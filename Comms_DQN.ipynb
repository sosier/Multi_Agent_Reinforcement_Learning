# %% [markdown]
# # Communication Simple Spread - DQN

# %%
# %load_ext autoreload
# %autoreload 2

from collections import namedtuple
import imageio
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import simple_spread_comms

# Set up matplotlib:
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# Detect if GPU is available:
DEVICE = torch.device(
    "mps" if torch.backends.mps.is_available()
    else (
        "cuda" if torch.cuda.is_available()
        else "cpu"
    )
)

# Global params:
GAMMA = 0.99  # < 1 to encourage prioritization of immediate rewards

# %% [markdown]
# ## Set Up Environment

# %%
# Set up environment
# N = 2
env = simple_spread_comms.parallel_env(N = 2, comm_mode=4)

observations, _ = env.reset()
observation_dim = observations["agent_0"].shape[0]
num_actions = env.action_space("agent_0").n

print("num_agents = ", env.num_agents, env.agents)
print(f"{num_actions=}")
print(f"{observation_dim=}")

observations
# Out:
# num_agents =  2 ['agent_0', 'agent_1']
# num_actions=5
# observation_dim=11
# {'agent_0': array([ 0.        ,  0.        , -0.5379803 ,  0.94192654,  0.35311785,
#         -1.3687737 ,  0.1134484 , -1.0601516 ,  0.08892478, -1.2579427 ,
#          1.        ], dtype=float32),
#  'agent_1': array([ 0.        ,  0.        , -0.44905552, -0.3160161 ,  0.2641931 ,
#         -0.11083099,  0.02452361,  0.19779105, -0.08892478,  1.2579427 ,
#          0.        ], dtype=float32)}

# %% [markdown]
# ## Helpers

# %%
class DQN(nn.Module):
    def __init__(
            self,
            input_dim=observation_dim,
            layers=[],
            output_dim=num_actions,
            activation_function="ReLU",
            loss_function="huber_loss",
            **kwargs
        ):
        super().__init__()

        # Validate Inputs:
        assert len(layers) > 0

        if type(activation_function) == str:
            assert(activation_function in nn.__dict__), (
                "activation_function must be one of the activation functions " +
                "available in the torch.nn module, e.g. 'ReLU'"
            )
            activation_function = nn.__dict__[activation_function]
        
        if type(loss_function) == str:
            assert(loss_function in F.__dict__), (
                "loss_function must be one of the loss functions " +
                "available in the torch.nn.functional module, e.g. 'cross_entropy'"
            )
            loss_function = F.__dict__[loss_function]

        # ------------------------------
        # Actually Initialize the Model:
        # ------------------------------
        self.layers = nn.ModuleList()

        # Hidden MLP Layers:
        for i, layer_size in enumerate(layers):
            if i == 0:
                layer_in = input_dim
            else:
                layer_in = layers[i - 1]

            layer = nn.Sequential(
                nn.Linear(layer_in, layer_size),
                activation_function()
            )
            self.layers.append(layer)

        # Final Fully Connected Output Layer:
        self.layers.append(nn.Linear(layers[-1], output_dim))
        
        # Loss:
        self.loss_function = loss_function

    def copy_weights(self, other_model):
        self.load_state_dict(other_model.state_dict())

    def forward(self, X, targets=None):
        for layer in self.layers:
            X = layer(X)

        # Final layer's output is the logits:
        logits = X

        if targets is not None:
            loss = self.loss_function(logits, targets)
            return logits, loss
        else:
            return logits

# Models objects for holding all the models for an agent:
Models = namedtuple("Models", ["main", "target"])

def _initialize_models(model_size):
    # Model used for selecting actions (principal)
    model = DQN(layers=[model_size] * 2).to(DEVICE)
    
    # Then create the target model. This will periodically be copied from the principal network 
    target_model = DQN(layers=[model_size] * 2).to(DEVICE)

    # Make sure models are initialized identically:
    target_model.copy_weights(model)

    return Models(model, target_model)

def initialize_models(env, model_size):
    env.reset()  # Reset env to make sure agent list isn't empty
    return {agent: _initialize_models(model_size) for agent in env.agents}

def select_actions(env, observations, models, epsilon):
    # Epsilon greedy
    if np.random.random() < epsilon:
        # Take random actions:
        actions = {agent: env.action_space(agent).sample() for agent in env.agents}
    else:
        # Predict action Q-values
        # From environment observations
        actions = {}
        for agent, model in models.items():
            model.main.eval()
            actions[agent] = model.main(
                # Observation (state) as tensor
                torch.tensor(observations[agent]).to(DEVICE)
            ).argmax(dim=-1).item()
    
    return actions

class ReplayBuffer():
    def __init__(
            self,
            max_size,
            state_dim=observation_dim,
            action_dim=1,
            reward_dim=1,
        ):
        self.history = []
        self.max_size = max_size
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.reward_dim = reward_dim
    
    @property
    def size(self):
        return len(self.history)
    
    def states(self, i):
        return self.history[i, :self.state_dim]

    def actions(self, i):
        return self.history[i, self.state_dim:(self.state_dim + self.action_dim)]

    def rewards(self, i):
        return self.history[
            i,
            (self.state_dim + self.action_dim)
            :(self.state_dim + self.action_dim + self.reward_dim)
        ]

    def state_nexts(self, i):
        return self.history[i, -self.state_dim:]
    
    def store(self, state, action, reward, state_next):
        if self.action_dim == 1: action = [action]
        if self.reward_dim == 1: reward = [reward]

        SARS = np.concatenate(
            [state, action, reward, state_next],
            dtype="float32"
        ).reshape(1, -1)

        if self.size == 0:
            self.history = SARS
        else:
            self.history = np.concatenate([self.history, SARS], axis=0)
    
        # Don't let the memory grow beyond the limit
        if self.size > self.max_size:
            self.history = self.history[1:]

    def sample(self, n):
        #  Sample a set of batch_size memories from the history
        sample_ids = np.random.choice(
            np.arange(self.size), size=n, replace=False
        )

        states = torch.tensor(self.states(sample_ids)).to(DEVICE)
        actions = torch.tensor(self.actions(sample_ids)).to(DEVICE)
        rewards = torch.tensor(self.rewards(sample_ids)).to(DEVICE)
        state_nexts = torch.tensor(self.state_nexts(sample_ids)).to(DEVICE)

        return states, actions, rewards, state_nexts

def train_one_step(models, memories, optimizers, batch_size=128):
    losses = {}

    for agent, model in models.items():
        #  Sample a set of batch_size memories from the history
        states, actions, rewards, state_nexts = memories[agent].sample(batch_size)

        # Create for the sample states the targets (r+gamma * max Q(...) )
        model.target.eval()
        Q_next_state = model.target(state_nexts)
        Q_targets = rewards + GAMMA * Q_next_state.max(axis=-1).values.view(-1, 1)

        # Q values to train:
        model.main.train()
        Q_values = model.main(states)
        # Pluck out the relevant actions only
        Q_of_actions = Q_values.gather(1, actions.to(int))

        # Calculate loss and perform optimization step:
        loss = model.main.loss_function(Q_of_actions, Q_targets)
        optimizers[agent].zero_grad()
        loss.backward()
        optimizers[agent].step()

        losses[agent] = loss.item()
    
    return losses

# Build validation dateset of held out states for use in tracking avg. max Q as
# a training validation / debugging metric:
def generate_validation_data(env=env, n=100):
    env.reset()  # Reset env to make sure agent list isn't empty
    validation_data = {agent: [] for agent in env.agents}

    for episode in range(n):
        observations, _ = env.reset()

        while env.agents:
            for agent in env.agents:
                validation_data[agent].append(observations[agent])

            # Take random actions:
            actions = {agent: env.action_space(agent).sample() for agent in env.agents}
            # Follow selected actions:
            observations, _, _, _, _ = env.step(actions)

    env.reset()  # Reset env to make sure agent list isn't empty
    validation_data = {
        agent: torch.tensor(np.array(validation_data[agent])).to(DEVICE)
        for agent in env.agents
    }
    return validation_data

def calc_avg_max_Q(models, validation_data):
    avg_max_Qs = {}
    for agent, model in models.items():
        model.main.eval()
        avg_max_Qs[agent] =\
            model.main(validation_data[agent]).max(axis=-1).values.mean().item()
    
    return avg_max_Qs

# %% [markdown]
# ## Validation Set Up

# %%
validation_data = generate_validation_data(env=env, n=100)

# %% [markdown]
# ## Training Loop

# %%
# ==============================================================================
# KEY PARAMS:
model_size = 128
batch_size = 128
learning_rate = 5e-4
max_episodes = 5000
max_memory = 10000  # Replay memory size
# how often to train your model - this allows you to speed up learning
# by not performing in every iteration learning. See also refernece paper
# you can set this value to other values like 1 as well to learn every time 
update_after_actions = 4
target_update_every = 1000  # How often to update the target network
epsilon = 0.1
# ==============================================================================

# Initialize models:
models = initialize_models(env, model_size)
optimizers = {
    agent: optim.Adam(model.main.parameters(), lr=learning_rate)
    for agent, model in models.items()
}

# Our Experience Replay memory (state, action, reward, next state)
env.reset()  # Reset env to make sure agent list isn't empty
memories = {agent: ReplayBuffer(max_memory) for agent in env.agents}
episode_reward_history = {agent: [] for agent in env.agents}
loss_history = {agent: [] for agent in env.agents}
avg_max_Q_history = {agent: [] for agent in env.agents}

# Tracking values
running_rewards = {agent: 0 for agent in env.agents}
episode_count = 0
timestep_count = 0

# Training Loop
for episode in range(max_episodes):
    observations, _ = env.reset()
    episode_rewards = {agent: 0 for agent in env.agents}

    while env.agents:
        timestep_count += 1
        actions = select_actions(env, observations, models, epsilon)

        # Follow selected actions
        observations_next, rewards, _, _, _ = env.step(actions)
        
        # Save action results
        for agent in rewards.keys():
            episode_rewards[agent] += rewards[agent]

            # Save action/states and other information in replay buffer
            memories[agent].store(
                observations[agent],
                actions[agent],
                rewards[agent],
                observations_next[agent]
            )

        observations = observations_next

        # Update every Xth frame to speed up (optional)
        # and if you have sufficient history
        if timestep_count % update_after_actions == 0 and timestep_count > batch_size:
            losses = train_one_step(models, memories, optimizers, batch_size)
            for agent, loss in losses.items():
                loss_history[agent].append(loss)

        if timestep_count % target_update_every == 0:
            # Update the the target network with new weights
            for model in models.values():
                model.target.copy_weights(model.main)

    # Record tracking statistics:
    for agent, episode_reward in episode_rewards.items():
        episode_reward_history[agent].append(episode_reward)
    
    for agent, avg_max_Q in calc_avg_max_Q(models, validation_data).items():
        avg_max_Q_history[agent].append(avg_max_Q)

    episode_count += 1

    # Logging:
    if episode_count % 50 == 0:
        # Log details
        # average reward of last 100:
        running_rewards = {
            agent: np.mean(episode_reward_history[agent][-100:])
            for agent in running_rewards.keys()
        }
        template = "running rewards: {} at episode {}, timestep {}, epsilon {}"
        print(template.format(running_rewards, episode_count, timestep_count, epsilon))
# Out:
# running rewards: {'agent_0': -25.75956376264618, 'agent_1': -25.75956376264618} at episode 50, timestep 1250, epsilon 0.1
# running rewards: {'agent_0': -25.56070212387739, 'agent_1': -25.56070212387739} at episode 100, timestep 2500, epsilon 0.1
# running rewards: {'agent_0': -24.245709295997326, 'agent_1': -24.245709295997326} at episode 150, timestep 3750, epsilon 0.1
# running rewards: {'agent_0': -22.592361290596934, 'agent_1': -22.592361290596934} at episode 200, timestep 5000, epsilon 0.1
# running rewards: {'agent_0': -20.069138754450368, 'agent_1': -20.069138754450368} at episode 250, timestep 6250, epsilon 0.1
# running rewards: {'agent_0': -16.911325882577, 'agent_1': -16.911325882577} at episode 300, timestep 7500, epsilon 0.1
# running rewards: {'agent_0': -15.602986922756191, 'agent_1': -15.602986922756191} at episode 350, timestep 8750, epsilon 0.1
# running rewards: {'agent_0': -15.6771490687756, 'agent_1': -15.6771490687756} at episode 400, timestep 10000, epsilon 0.1
# running rewards: {'agent_0': -15.373598813559232, 'agent_1': -15.373598813559232} at episode 450, timestep 11250, epsilon 0.1
# running rewards: {'agent_0': -14.620879488584347, 'agent_1': -14.620879488584347} at episode 500, timestep 12500, epsilon 0.1
# running rewards: {'agent_0': -14.147025278847458, 'agent_1': -14.147025278847458} at episode 550, timestep 13750, epsilon 0.1
# running rewards: {'agent_0': -14.42387633911601, 'agent_1': -14.42387633911601} at episode 600, timestep 15000, epsilon 0.1
# running rewards: {'agent_0': -14.056498039659811, 'agent_1': -14.056498039659811} at episode 650, timestep 16250, epsilon 0.1
# running rewards: {'agent_0': -13.684440543857397, 'agent_1': -13.684440543857397} at episode 700, timestep 17500, epsilon 0.1
# running rewards: {'agent_0': -14.490430335794233, 'agent_1': -14.490430335794233} at episode 750, timestep 18750, epsilon 0.1
# running rewards: {'agent_0': -14.237513026840482, 'agent_1': -14.237513026840482} at episode 800, timestep 20000, epsilon 0.1
# running rewards: {'agent_0': -13.592287467127342, 'agent_1': -13.592287467127342} at episode 850, timestep 21250, epsilon 0.1
# running rewards: {'agent_0': -13.39794037218026, 'agent_1': -13.39794037218026} at episode 900, timestep 22500, epsilon 0.1
# running rewards: {'agent_0': -13.395550744875926, 'agent_1': -13.395550744875926} at episode 950, timestep 23750, epsilon 0.1
# running rewards: {'agent_0': -13.518150031988489, 'agent_1': -13.518150031988489} at episode 1000, timestep 25000, epsilon 0.1
# running rewards: {'agent_0': -13.019220676592646, 'agent_1': -13.019220676592646} at episode 1050, timestep 26250, epsilon 0.1
# running rewards: {'agent_0': -12.302179091701412, 'agent_1': -12.302179091701412} at episode 1100, timestep 27500, epsilon 0.1
# running rewards: {'agent_0': -12.55187973049623, 'agent_1': -12.55187973049623} at episode 1150, timestep 28750, epsilon 0.1
# running rewards: {'agent_0': -12.743076473435766, 'agent_1': -12.743076473435766} at episode 1200, timestep 30000, epsilon 0.1
# running rewards: {'agent_0': -12.468345445354323, 'agent_1': -12.468345445354323} at episode 1250, timestep 31250, epsilon 0.1
# running rewards: {'agent_0': -12.551943255495276, 'agent_1': -12.551943255495276} at episode 1300, timestep 32500, epsilon 0.1
# running rewards: {'agent_0': -11.74707319696507, 'agent_1': -11.74707319696507} at episode 1350, timestep 33750, epsilon 0.1
# running rewards: {'agent_0': -11.348246932608145, 'agent_1': -11.348246932608145} at episode 1400, timestep 35000, epsilon 0.1
# running rewards: {'agent_0': -11.686588145578954, 'agent_1': -11.686588145578954} at episode 1450, timestep 36250, epsilon 0.1
# running rewards: {'agent_0': -10.942554891970863, 'agent_1': -10.942554891970863} at episode 1500, timestep 37500, epsilon 0.1
# running rewards: {'agent_0': -10.711058417233923, 'agent_1': -10.711058417233923} at episode 1550, timestep 38750, epsilon 0.1
# running rewards: {'agent_0': -11.25369272852144, 'agent_1': -11.25369272852144} at episode 1600, timestep 40000, epsilon 0.1
# running rewards: {'agent_0': -11.611013959409757, 'agent_1': -11.611013959409757} at episode 1650, timestep 41250, epsilon 0.1
# running rewards: {'agent_0': -11.321313300812417, 'agent_1': -11.321313300812417} at episode 1700, timestep 42500, epsilon 0.1
# running rewards: {'agent_0': -10.870925975873636, 'agent_1': -10.870925975873636} at episode 1750, timestep 43750, epsilon 0.1
# running rewards: {'agent_0': -11.31346516229423, 'agent_1': -11.31346516229423} at episode 1800, timestep 45000, epsilon 0.1
# running rewards: {'agent_0': -11.572966817547716, 'agent_1': -11.572966817547716} at episode 1850, timestep 46250, epsilon 0.1
# running rewards: {'agent_0': -11.086366505875763, 'agent_1': -11.086366505875763} at episode 1900, timestep 47500, epsilon 0.1
# running rewards: {'agent_0': -10.671156347764969, 'agent_1': -10.671156347764969} at episode 1950, timestep 48750, epsilon 0.1
# running rewards: {'agent_0': -11.188592998915809, 'agent_1': -11.188592998915809} at episode 2000, timestep 50000, epsilon 0.1
# running rewards: {'agent_0': -10.879591132179518, 'agent_1': -10.879591132179518} at episode 2050, timestep 51250, epsilon 0.1
# running rewards: {'agent_0': -10.011922749174861, 'agent_1': -10.011922749174861} at episode 2100, timestep 52500, epsilon 0.1
# running rewards: {'agent_0': -10.8101506442642, 'agent_1': -10.8101506442642} at episode 2150, timestep 53750, epsilon 0.1
# running rewards: {'agent_0': -10.98047469536234, 'agent_1': -10.98047469536234} at episode 2200, timestep 55000, epsilon 0.1
# running rewards: {'agent_0': -10.319777837032932, 'agent_1': -10.319777837032932} at episode 2250, timestep 56250, epsilon 0.1
# running rewards: {'agent_0': -10.305545408590344, 'agent_1': -10.305545408590344} at episode 2300, timestep 57500, epsilon 0.1
# running rewards: {'agent_0': -10.244697098871523, 'agent_1': -10.244697098871523} at episode 2350, timestep 58750, epsilon 0.1
# running rewards: {'agent_0': -10.300655919302235, 'agent_1': -10.300655919302235} at episode 2400, timestep 60000, epsilon 0.1
# running rewards: {'agent_0': -10.725607233380813, 'agent_1': -10.725607233380813} at episode 2450, timestep 61250, epsilon 0.1
# running rewards: {'agent_0': -11.139277137593636, 'agent_1': -11.139277137593636} at episode 2500, timestep 62500, epsilon 0.1
# running rewards: {'agent_0': -11.163034471667139, 'agent_1': -11.163034471667139} at episode 2550, timestep 63750, epsilon 0.1
# running rewards: {'agent_0': -11.170399501543539, 'agent_1': -11.170399501543539} at episode 2600, timestep 65000, epsilon 0.1
# running rewards: {'agent_0': -10.745954906032928, 'agent_1': -10.745954906032928} at episode 2650, timestep 66250, epsilon 0.1
# running rewards: {'agent_0': -10.337884188188257, 'agent_1': -10.337884188188257} at episode 2700, timestep 67500, epsilon 0.1
# running rewards: {'agent_0': -10.191907379132243, 'agent_1': -10.191907379132243} at episode 2750, timestep 68750, epsilon 0.1
# running rewards: {'agent_0': -9.980794558158953, 'agent_1': -9.980794558158953} at episode 2800, timestep 70000, epsilon 0.1
# running rewards: {'agent_0': -10.759533278011956, 'agent_1': -10.759533278011956} at episode 2850, timestep 71250, epsilon 0.1
# running rewards: {'agent_0': -11.386263495286489, 'agent_1': -11.386263495286489} at episode 2900, timestep 72500, epsilon 0.1
# running rewards: {'agent_0': -11.494043599797857, 'agent_1': -11.494043599797857} at episode 2950, timestep 73750, epsilon 0.1
# running rewards: {'agent_0': -11.631523021122122, 'agent_1': -11.631523021122122} at episode 3000, timestep 75000, epsilon 0.1
# running rewards: {'agent_0': -11.350368943909999, 'agent_1': -11.350368943909999} at episode 3050, timestep 76250, epsilon 0.1
# running rewards: {'agent_0': -11.085028970103995, 'agent_1': -11.085028970103995} at episode 3100, timestep 77500, epsilon 0.1
# running rewards: {'agent_0': -10.739220889157814, 'agent_1': -10.739220889157814} at episode 3150, timestep 78750, epsilon 0.1
# running rewards: {'agent_0': -10.45486526835801, 'agent_1': -10.45486526835801} at episode 3200, timestep 80000, epsilon 0.1
# running rewards: {'agent_0': -10.916423111768536, 'agent_1': -10.916423111768536} at episode 3250, timestep 81250, epsilon 0.1
# running rewards: {'agent_0': -10.394844359740016, 'agent_1': -10.394844359740016} at episode 3300, timestep 82500, epsilon 0.1
# running rewards: {'agent_0': -10.166199420258318, 'agent_1': -10.166199420258318} at episode 3350, timestep 83750, epsilon 0.1
# running rewards: {'agent_0': -10.619457867474118, 'agent_1': -10.619457867474118} at episode 3400, timestep 85000, epsilon 0.1
# running rewards: {'agent_0': -10.363764550601399, 'agent_1': -10.363764550601399} at episode 3450, timestep 86250, epsilon 0.1
# running rewards: {'agent_0': -10.508923958885989, 'agent_1': -10.508923958885989} at episode 3500, timestep 87500, epsilon 0.1
# running rewards: {'agent_0': -10.669669535551634, 'agent_1': -10.669669535551634} at episode 3550, timestep 88750, epsilon 0.1
# running rewards: {'agent_0': -10.68589021993698, 'agent_1': -10.68589021993698} at episode 3600, timestep 90000, epsilon 0.1
# running rewards: {'agent_0': -10.405282232820873, 'agent_1': -10.405282232820873} at episode 3650, timestep 91250, epsilon 0.1
# running rewards: {'agent_0': -10.203069505267573, 'agent_1': -10.203069505267573} at episode 3700, timestep 92500, epsilon 0.1
# running rewards: {'agent_0': -10.310683556408323, 'agent_1': -10.310683556408323} at episode 3750, timestep 93750, epsilon 0.1
# running rewards: {'agent_0': -10.131424855593973, 'agent_1': -10.131424855593973} at episode 3800, timestep 95000, epsilon 0.1
# running rewards: {'agent_0': -9.648886607080001, 'agent_1': -9.648886607080001} at episode 3850, timestep 96250, epsilon 0.1
# running rewards: {'agent_0': -10.403742371673452, 'agent_1': -10.403742371673452} at episode 3900, timestep 97500, epsilon 0.1
# running rewards: {'agent_0': -10.965546167943764, 'agent_1': -10.965546167943764} at episode 3950, timestep 98750, epsilon 0.1
# running rewards: {'agent_0': -10.147804482084721, 'agent_1': -10.147804482084721} at episode 4000, timestep 100000, epsilon 0.1
# running rewards: {'agent_0': -9.97075216939407, 'agent_1': -9.97075216939407} at episode 4050, timestep 101250, epsilon 0.1
# running rewards: {'agent_0': -10.12428532930084, 'agent_1': -10.12428532930084} at episode 4100, timestep 102500, epsilon 0.1
# running rewards: {'agent_0': -10.310354505650839, 'agent_1': -10.310354505650839} at episode 4150, timestep 103750, epsilon 0.1
# running rewards: {'agent_0': -10.378156640647592, 'agent_1': -10.378156640647592} at episode 4200, timestep 105000, epsilon 0.1
# running rewards: {'agent_0': -10.282134522859895, 'agent_1': -10.282134522859895} at episode 4250, timestep 106250, epsilon 0.1
# running rewards: {'agent_0': -10.194602112830031, 'agent_1': -10.194602112830031} at episode 4300, timestep 107500, epsilon 0.1
# running rewards: {'agent_0': -10.545661762515476, 'agent_1': -10.545661762515476} at episode 4350, timestep 108750, epsilon 0.1
# running rewards: {'agent_0': -10.21781540078756, 'agent_1': -10.21781540078756} at episode 4400, timestep 110000, epsilon 0.1
# running rewards: {'agent_0': -9.523058942069621, 'agent_1': -9.523058942069621} at episode 4450, timestep 111250, epsilon 0.1
# running rewards: {'agent_0': -9.447441107710718, 'agent_1': -9.447441107710718} at episode 4500, timestep 112500, epsilon 0.1
# running rewards: {'agent_0': -9.693747541683916, 'agent_1': -9.693747541683916} at episode 4550, timestep 113750, epsilon 0.1
# running rewards: {'agent_0': -10.307078915511477, 'agent_1': -10.307078915511477} at episode 4600, timestep 115000, epsilon 0.1
# running rewards: {'agent_0': -10.403192940147056, 'agent_1': -10.403192940147056} at episode 4650, timestep 116250, epsilon 0.1
# running rewards: {'agent_0': -10.253308713470574, 'agent_1': -10.253308713470574} at episode 4700, timestep 117500, epsilon 0.1
# running rewards: {'agent_0': -10.264884003984298, 'agent_1': -10.264884003984298} at episode 4750, timestep 118750, epsilon 0.1
# running rewards: {'agent_0': -10.326942177417653, 'agent_1': -10.326942177417653} at episode 4800, timestep 120000, epsilon 0.1
# running rewards: {'agent_0': -10.110400963786388, 'agent_1': -10.110400963786388} at episode 4850, timestep 121250, epsilon 0.1
# running rewards: {'agent_0': -10.205319758409269, 'agent_1': -10.205319758409269} at episode 4900, timestep 122500, epsilon 0.1
# running rewards: {'agent_0': -10.146774447143395, 'agent_1': -10.146774447143395} at episode 4950, timestep 123750, epsilon 0.1
# running rewards: {'agent_0': -10.101423698903332, 'agent_1': -10.101423698903332} at episode 5000, timestep 125000, epsilon 0.1

# %%
# Training Plots (for Debugging)
env.reset()  # Reset env to make sure agent list isn't empty

for agent in env.agents:
    # Raw Reward
    plt.title(f"{agent}: Reward / Episode")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.plot(np.arange(len(episode_reward_history[agent])), episode_reward_history[agent])
    plt.show()

# Rolling Average Reward:
def moving_average(x, w):
    # Source: https://stackoverflow.com/a/54628145
    return np.convolve(x, np.ones(w), 'valid') / w

for agent in env.agents:
    rolling_means = moving_average(episode_reward_history[agent], 100)

    # Rolling Average
    plt.title(f"{agent}: Rolling Mean Reward")
    plt.xlabel("Episode") 
    plt.ylabel("Average Total Reward (Last 100 Episodes)")
    plt.plot(np.arange(len(rolling_means)) + 100, rolling_means)
    plt.show()

for agent in env.agents:
    # Loss Trend
    plt.title(f"{agent}: Loss History")
    plt.xlabel("Training Step") 
    plt.ylabel("Loss")
    plt.plot(np.arange(len(loss_history[agent])), loss_history[agent])
    plt.show()

for agent in env.agents:
    # Avg. Max Q Trend
    plt.title(f"{agent}: Avg. Max Q Value History")
    plt.xlabel("Episode") 
    plt.ylabel("Avg. Max Q Value")
    plt.plot(np.arange(len(avg_max_Q_history[agent])), avg_max_Q_history[agent])
    plt.show()

# %% [markdown]
# ## Final Evaluation

# %%
def eval_greedy_model(env, models):
    env.reset()  # Reset env to make sure agent list isn't empty

    # Tracking values
    final_eval_rewards = {agent: [] for agent in env.agents}
    
    #update to 500 for gif looping
    for episode in range(500):
        observations, _ = env.reset()
        episode_rewards = {agent: 0 for agent in env.agents}

        while env.agents:
            actions = select_actions(env, observations, models, epsilon=0)

            # Follow selected actions
            observations_next, rewards, _, _, _ = env.step(actions)
            
            # Save action results
            for agent in rewards.keys():
                episode_rewards[agent] += rewards[agent]

            observations = observations_next

        # Record tracking statistics:
        for agent, episode_reward in episode_rewards.items():
            final_eval_rewards[agent].append(episode_reward)


    avg_greedy_reward = {
        agent: np.mean(final_eval_reward)
        for agent, final_eval_reward in final_eval_rewards.items()
    }

    return avg_greedy_reward, final_eval_rewards

# %%
avg_greedy_reward, final_eval_rewards = eval_greedy_model(env, models)

print(avg_greedy_reward)

env.reset()  # Reset env to make sure agent list isn't empty

for agent in env.agents:
    # Raw Reward
    plt.title("Reward / Episode")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.plot(np.arange(len(final_eval_rewards[agent])), final_eval_rewards[agent])
    plt.show()
# Out:
# {'agent_0': -9.861369884688731, 'agent_1': -9.861369884688731}

# %%
# Visualize full episode
rendered_env = simple_spread_comms.parallel_env(N = 2, comm_mode=4, render_mode="rgb_array")
frames = []

observations, _ = rendered_env.reset()
frames.append(rendered_env.render())

while rendered_env.agents:
    # this is where you would insert your policy
    actions = select_actions(rendered_env, observations, models, epsilon=0)

    observations, _, _, _, _ = rendered_env.step(actions)
    frames.append(rendered_env.render())

rendered_env.close()

imageio.mimwrite(
    "rendered_episode.gif",
    frames,
    loop=0  # Infinite loop gif
)
