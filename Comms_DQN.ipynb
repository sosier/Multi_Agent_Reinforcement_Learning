# %% [markdown]
# # Communication Simple Spread - DQN

# %%
# %load_ext autoreload
# %autoreload 2

from collections import namedtuple
import imageio
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import simple_spread_comms

# Set up matplotlib:
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# Detect if GPU is available:
DEVICE = torch.device(
    "mps" if torch.backends.mps.is_available()
    else (
        "cuda" if torch.cuda.is_available()
        else "cpu"
    )
)

# Global params:
GAMMA = 0.99  # < 1 to encourage prioritization of immediate rewards

# %% [markdown]
# ## Set Up Environment

# %%
# Set up environment
# N = 2
env = simple_spread_comms.parallel_env(n_agents = 4, n_landmarks = 4, comm_mode=2)

observations, _ = env.reset()
observation_dim = observations["agent_0"].shape[0]
num_actions = env.action_space("agent_0").n

print("num_agents = ", env.num_agents, env.agents)
print(f"{num_actions=}")
print(f"{observation_dim=}")

observations
# Out:
# num_agents =  4 ['agent_0', 'agent_1', 'agent_2', 'agent_3']
# num_actions=5
# observation_dim=24
# {'agent_0': array([ 0.        ,  0.        , -0.81961083, -0.8038313 ,  0.65365356,
#          0.9768846 ,  0.08935556,  1.1199083 ,  1.4076551 ,  1.0878792 ,
#          0.1136082 ,  0.69633454,  0.15569848,  0.39982423,  0.67455137,
#         -0.06554183,  0.30997762,  1.2621402 ,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ], dtype=float32),
#  'agent_1': array([ 0.        ,  0.        , -0.66391236, -0.40400705,  0.49795505,
#          0.57706034, -0.06634293,  0.7200841 ,  1.2519566 ,  0.68805486,
#         -0.04209028,  0.29651028, -0.15569848, -0.39982423,  0.5188529 ,
#         -0.46536607,  0.15427914,  0.86231595,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ], dtype=float32),
#  'agent_2': array([ 0.        ,  0.        , -0.14505947, -0.86937314, -0.02089781,
#          1.0424265 , -0.5851958 ,  1.1854501 ,  0.73310375,  1.1534209 ,
#         -0.5609432 ,  0.76187634, -0.67455137,  0.06554183, -0.5188529 ,
#          0.46536607, -0.36457372,  1.327682  ,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ], dtype=float32),
#  'agent_3': array([ 0.        ,  0.        , -0.5096332 ,  0.4583089 ,  0.3436759 ,
#         -0.2852556 , -0.22062208, -0.1422319 ,  1.0976775 , -0.17426106,
#         -0.19636942, -0.5658057 , -0.30997762, -1.2621402 , -0.15427914,
#         -0.86231595,  0.36457372, -1.327682  ,  0.        ,  0.        ,
#          0.        ,  0.        ,  0.        ,  0.        ], dtype=float32)}

# %% [markdown]
# ## Helpers

# %%
class DQN(nn.Module):
    def __init__(
            self,
            input_dim=observation_dim,
            layers=[],
            output_dim=num_actions,
            activation_function="ReLU",
            loss_function="huber_loss",
            **kwargs
        ):
        super().__init__()

        # Validate Inputs:
        assert len(layers) > 0

        if type(activation_function) == str:
            assert(activation_function in nn.__dict__), (
                "activation_function must be one of the activation functions " +
                "available in the torch.nn module, e.g. 'ReLU'"
            )
            activation_function = nn.__dict__[activation_function]
        
        if type(loss_function) == str:
            assert(loss_function in F.__dict__), (
                "loss_function must be one of the loss functions " +
                "available in the torch.nn.functional module, e.g. 'cross_entropy'"
            )
            loss_function = F.__dict__[loss_function]

        # ------------------------------
        # Actually Initialize the Model:
        # ------------------------------
        self.layers = nn.ModuleList()

        # Hidden MLP Layers:
        for i, layer_size in enumerate(layers):
            if i == 0:
                layer_in = input_dim
            else:
                layer_in = layers[i - 1]

            layer = nn.Sequential(
                nn.Linear(layer_in, layer_size),
                activation_function()
            )
            self.layers.append(layer)

        # Final Fully Connected Output Layer:
        self.layers.append(nn.Linear(layers[-1], output_dim))
        
        # Loss:
        self.loss_function = loss_function

    def copy_weights(self, other_model):
        self.load_state_dict(other_model.state_dict())

    def forward(self, X, targets=None):
        for layer in self.layers:
            X = layer(X)

        # Final layer's output is the logits:
        logits = X

        if targets is not None:
            loss = self.loss_function(logits, targets)
            return logits, loss
        else:
            return logits

# Models objects for holding all the models for an agent:
Models = namedtuple("Models", ["main", "target"])

def _initialize_models(model_size):
    # Model used for selecting actions (principal)
    model = DQN(layers=[model_size] * 2).to(DEVICE)
    
    # Then create the target model. This will periodically be copied from the principal network 
    target_model = DQN(layers=[model_size] * 2).to(DEVICE)

    # Make sure models are initialized identically:
    target_model.copy_weights(model)

    return Models(model, target_model)

def initialize_models(env, model_size):
    env.reset()  # Reset env to make sure agent list isn't empty
    return {agent: _initialize_models(model_size) for agent in env.agents}

def select_actions(env, observations, models, epsilon):
    # Epsilon greedy
    if np.random.random() < epsilon:
        # Take random actions:
        actions = {agent: env.action_space(agent).sample() for agent in env.agents}
    else:
        # Predict action Q-values
        # From environment observations
        actions = {}
        for agent, model in models.items():
            model.main.eval()
            actions[agent] = model.main(
                # Observation (state) as tensor
                torch.tensor(observations[agent]).to(DEVICE)
            ).argmax(dim=-1).item()
    
    return actions

class ReplayBuffer():
    def __init__(
            self,
            max_size,
            state_dim=observation_dim,
            action_dim=1,
            reward_dim=1,
        ):
        self.history = []
        self.max_size = max_size
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.reward_dim = reward_dim
    
    @property
    def size(self):
        return len(self.history)
    
    def states(self, i):
        return self.history[i, :self.state_dim]

    def actions(self, i):
        return self.history[i, self.state_dim:(self.state_dim + self.action_dim)]

    def rewards(self, i):
        return self.history[
            i,
            (self.state_dim + self.action_dim)
            :(self.state_dim + self.action_dim + self.reward_dim)
        ]

    def state_nexts(self, i):
        return self.history[i, -self.state_dim:]
    
    def store(self, state, action, reward, state_next):
        if self.action_dim == 1: action = [action]
        if self.reward_dim == 1: reward = [reward]

        SARS = np.concatenate(
            [state, action, reward, state_next],
            dtype="float32"
        ).reshape(1, -1)

        if self.size == 0:
            self.history = SARS
        else:
            self.history = np.concatenate([self.history, SARS], axis=0)
    
        # Don't let the memory grow beyond the limit
        if self.size > self.max_size:
            self.history = self.history[1:]

    def sample(self, n):
        #  Sample a set of batch_size memories from the history
        sample_ids = np.random.choice(
            np.arange(self.size), size=n, replace=False
        )

        states = torch.tensor(self.states(sample_ids)).to(DEVICE)
        actions = torch.tensor(self.actions(sample_ids)).to(DEVICE)
        rewards = torch.tensor(self.rewards(sample_ids)).to(DEVICE)
        state_nexts = torch.tensor(self.state_nexts(sample_ids)).to(DEVICE)

        return states, actions, rewards, state_nexts

def train_one_step(models, memories, optimizers, batch_size=128):
    losses = {}

    for agent, model in models.items():
        #  Sample a set of batch_size memories from the history
        states, actions, rewards, state_nexts = memories[agent].sample(batch_size)

        # Create for the sample states the targets (r+gamma * max Q(...) )
        model.target.eval()
        Q_next_state = model.target(state_nexts)
        Q_targets = rewards + GAMMA * Q_next_state.max(axis=-1).values.view(-1, 1)

        # Q values to train:
        model.main.train()
        Q_values = model.main(states)
        # Pluck out the relevant actions only
        Q_of_actions = Q_values.gather(1, actions.to(int))

        # Calculate loss and perform optimization step:
        loss = model.main.loss_function(Q_of_actions, Q_targets)
        optimizers[agent].zero_grad()
        loss.backward()
        optimizers[agent].step()

        losses[agent] = loss.item()
    
    return losses

# Build validation dateset of held out states for use in tracking avg. max Q as
# a training validation / debugging metric:
def generate_validation_data(env=env, n=100):
    env.reset()  # Reset env to make sure agent list isn't empty
    validation_data = {agent: [] for agent in env.agents}

    for episode in range(n):
        observations, _ = env.reset()

        while env.agents:
            for agent in env.agents:
                validation_data[agent].append(observations[agent])

            # Take random actions:
            actions = {agent: env.action_space(agent).sample() for agent in env.agents}
            # Follow selected actions:
            observations, _, _, _, _ = env.step(actions)

    env.reset()  # Reset env to make sure agent list isn't empty
    validation_data = {
        agent: torch.tensor(np.array(validation_data[agent])).to(DEVICE)
        for agent in env.agents
    }
    return validation_data

def calc_avg_max_Q(models, validation_data):
    avg_max_Qs = {}
    for agent, model in models.items():
        model.main.eval()
        avg_max_Qs[agent] =\
            model.main(validation_data[agent]).max(axis=-1).values.mean().item()
    
    return avg_max_Qs

# %% [markdown]
# ## Validation Set Up

# %%
validation_data = generate_validation_data(env=env, n=100)

# %% [markdown]
# ## Training Loop

# %%
# ==============================================================================
# KEY PARAMS:
model_size = 128
batch_size = 128
learning_rate = 5e-4
max_episodes = 5000
max_memory = 10000  # Replay memory size
# how often to train your model - this allows you to speed up learning
# by not performing in every iteration learning. See also refernece paper
# you can set this value to other values like 1 as well to learn every time 
update_after_actions = 4
target_update_every = 1000  # How often to update the target network
epsilon = 0.1
# ==============================================================================

# Initialize models:
models = initialize_models(env, model_size)
optimizers = {
    agent: optim.Adam(model.main.parameters(), lr=learning_rate)
    for agent, model in models.items()
}

# Our Experience Replay memory (state, action, reward, next state)
env.reset()  # Reset env to make sure agent list isn't empty
memories = {agent: ReplayBuffer(max_memory) for agent in env.agents}
episode_reward_history = {agent: [] for agent in env.agents}
loss_history = {agent: [] for agent in env.agents}
avg_max_Q_history = {agent: [] for agent in env.agents}

# Tracking values
running_rewards = {agent: 0 for agent in env.agents}
episode_count = 0
timestep_count = 0

# Training Loop
for episode in range(max_episodes):
    observations, _ = env.reset()
    episode_rewards = {agent: 0 for agent in env.agents}

    while env.agents:
        timestep_count += 1
        actions = select_actions(env, observations, models, epsilon)

        # Follow selected actions
        observations_next, rewards, _, _, _ = env.step(actions)
        
        # Save action results
        for agent in rewards.keys():
            episode_rewards[agent] += rewards[agent]

            # Save action/states and other information in replay buffer
            memories[agent].store(
                observations[agent],
                actions[agent],
                rewards[agent],
                observations_next[agent]
            )

        observations = observations_next

        # Update every Xth frame to speed up (optional)
        # and if you have sufficient history
        if timestep_count % update_after_actions == 0 and timestep_count > batch_size:
            losses = train_one_step(models, memories, optimizers, batch_size)
            for agent, loss in losses.items():
                loss_history[agent].append(loss)

        if timestep_count % target_update_every == 0:
            # Update the the target network with new weights
            for model in models.values():
                model.target.copy_weights(model.main)

    # Record tracking statistics:
    for agent, episode_reward in episode_rewards.items():
        episode_reward_history[agent].append(episode_reward)
    
    for agent, avg_max_Q in calc_avg_max_Q(models, validation_data).items():
        avg_max_Q_history[agent].append(avg_max_Q)

    episode_count += 1

    # Logging:
    if episode_count % 50 == 0:
        # Log details
        # average reward of last 100:
        running_rewards = {
            agent: np.mean(episode_reward_history[agent][-100:])
            for agent in running_rewards.keys()
        }
        template = "running rewards: {} at episode {}, timestep {}, epsilon {}"
        print(template.format(running_rewards, episode_count, timestep_count, epsilon))
# Out:
# running rewards: {'agent_0': -39.04415125301553, 'agent_1': -38.87415125301553, 'agent_2': -39.074151253015536, 'agent_3': -39.04415125301553} at episode 50, timestep 1250, epsilon 0.1
# running rewards: {'agent_0': -37.01063921172126, 'agent_1': -36.88063921172127, 'agent_2': -37.000639211721264, 'agent_3': -36.820639211721264} at episode 100, timestep 2500, epsilon 0.1
# running rewards: {'agent_0': -33.598714795942236, 'agent_1': -33.54871479594223, 'agent_2': -33.55871479594223, 'agent_3': -33.358714795942234} at episode 150, timestep 3750, epsilon 0.1
# running rewards: {'agent_0': -31.667577591358476, 'agent_1': -31.512577591358475, 'agent_2': -31.672577591358476, 'agent_3': -31.637577591358475} at episode 200, timestep 5000, epsilon 0.1
# running rewards: {'agent_0': -30.36525700097327, 'agent_1': -30.08025700097327, 'agent_2': -30.37525700097327, 'agent_3': -30.34025700097327} at episode 250, timestep 6250, epsilon 0.1
# running rewards: {'agent_0': -29.177912353427605, 'agent_1': -28.927912353427605, 'agent_2': -29.212912353427605, 'agent_3': -29.142912353427604} at episode 300, timestep 7500, epsilon 0.1
# running rewards: {'agent_0': -28.799430253555332, 'agent_1': -28.654430253555333, 'agent_2': -28.734430253555335, 'agent_3': -28.659430253555332} at episode 350, timestep 8750, epsilon 0.1
# running rewards: {'agent_0': -28.261724901749957, 'agent_1': -27.991724901749958, 'agent_2': -28.161724901749963, 'agent_3': -28.101724901749957} at episode 400, timestep 10000, epsilon 0.1
# running rewards: {'agent_0': -27.889596563341104, 'agent_1': -27.41459656334111, 'agent_2': -27.844596563341106, 'agent_3': -27.789596563341107} at episode 450, timestep 11250, epsilon 0.1
# running rewards: {'agent_0': -27.32349030993198, 'agent_1': -26.82349030993198, 'agent_2': -27.25349030993198, 'agent_3': -27.33349030993198} at episode 500, timestep 12500, epsilon 0.1
# running rewards: {'agent_0': -26.401394534681913, 'agent_1': -26.001394534681914, 'agent_2': -26.23139453468191, 'agent_3': -26.411394534681914} at episode 550, timestep 13750, epsilon 0.1
# running rewards: {'agent_0': -26.46901742144996, 'agent_1': -26.119017421449957, 'agent_2': -26.499017421449956, 'agent_3': -26.339017421449956} at episode 600, timestep 15000, epsilon 0.1
# running rewards: {'agent_0': -26.04794055387479, 'agent_1': -25.487940553874786, 'agent_2': -26.137940553874788, 'agent_3': -26.007940553874786} at episode 650, timestep 16250, epsilon 0.1
# running rewards: {'agent_0': -25.40111181431904, 'agent_1': -24.93611181431904, 'agent_2': -25.286111814319042, 'agent_3': -25.501111814319042} at episode 700, timestep 17500, epsilon 0.1
# running rewards: {'agent_0': -25.684634616203518, 'agent_1': -25.43463461620352, 'agent_2': -25.774634616203517, 'agent_3': -25.81463461620352} at episode 750, timestep 18750, epsilon 0.1
# running rewards: {'agent_0': -25.830818065150005, 'agent_1': -25.62081806515001, 'agent_2': -25.970818065150006, 'agent_3': -25.910818065150007} at episode 800, timestep 20000, epsilon 0.1
# running rewards: {'agent_0': -25.183016511894834, 'agent_1': -25.003016511894835, 'agent_2': -25.118016511894833, 'agent_3': -25.288016511894835} at episode 850, timestep 21250, epsilon 0.1
# running rewards: {'agent_0': -25.449764160572933, 'agent_1': -25.184764160572932, 'agent_2': -25.359764160572933, 'agent_3': -25.40476416057293} at episode 900, timestep 22500, epsilon 0.1
# running rewards: {'agent_0': -25.51534674081596, 'agent_1': -25.275346740815962, 'agent_2': -25.505346740815966, 'agent_3': -25.445346740815967} at episode 950, timestep 23750, epsilon 0.1
# running rewards: {'agent_0': -25.1844986951348, 'agent_1': -25.159498695134797, 'agent_2': -25.159498695134797, 'agent_3': -25.1844986951348} at episode 1000, timestep 25000, epsilon 0.1
# running rewards: {'agent_0': -25.648925885213465, 'agent_1': -25.563925885213465, 'agent_2': -25.483925885213466, 'agent_3': -25.518925885213466} at episode 1050, timestep 26250, epsilon 0.1
# running rewards: {'agent_0': -25.82305696892466, 'agent_1': -25.73305696892466, 'agent_2': -25.618056968924662, 'agent_3': -25.708056968924662} at episode 1100, timestep 27500, epsilon 0.1
# running rewards: {'agent_0': -24.906076148904866, 'agent_1': -25.121076148904866, 'agent_2': -24.89107614890487, 'agent_3': -24.94607614890487} at episode 1150, timestep 28750, epsilon 0.1
# running rewards: {'agent_0': -24.75038013995457, 'agent_1': -24.80538013995457, 'agent_2': -24.82538013995457, 'agent_3': -24.740380139954574} at episode 1200, timestep 30000, epsilon 0.1
# running rewards: {'agent_0': -25.926910624849306, 'agent_1': -25.901910624849307, 'agent_2': -25.976910624849307, 'agent_3': -25.931910624849305} at episode 1250, timestep 31250, epsilon 0.1
# running rewards: {'agent_0': -26.040390807240342, 'agent_1': -26.245390807240348, 'agent_2': -26.035390807240343, 'agent_3': -26.21039080724034} at episode 1300, timestep 32500, epsilon 0.1
# running rewards: {'agent_0': -25.51703901849544, 'agent_1': -25.62203901849544, 'agent_2': -25.47703901849544, 'agent_3': -25.67203901849544} at episode 1350, timestep 33750, epsilon 0.1
# running rewards: {'agent_0': -25.34605107774691, 'agent_1': -25.30605107774691, 'agent_2': -25.32605107774691, 'agent_3': -25.496051077746912} at episode 1400, timestep 35000, epsilon 0.1
# running rewards: {'agent_0': -25.846720925843737, 'agent_1': -25.85672092584374, 'agent_2': -25.92672092584374, 'agent_3': -25.986720925843738} at episode 1450, timestep 36250, epsilon 0.1
# running rewards: {'agent_0': -26.465243582393835, 'agent_1': -26.400243582393838, 'agent_2': -26.390243582393836, 'agent_3': -26.525243582393838} at episode 1500, timestep 37500, epsilon 0.1
# running rewards: {'agent_0': -26.11219450602754, 'agent_1': -26.017194506027543, 'agent_2': -26.032194506027544, 'agent_3': -26.13719450602754} at episode 1550, timestep 38750, epsilon 0.1
# running rewards: {'agent_0': -26.182764447348692, 'agent_1': -26.12276444734869, 'agent_2': -26.09776444734869, 'agent_3': -26.07776444734869} at episode 1600, timestep 40000, epsilon 0.1
# running rewards: {'agent_0': -26.68048575466969, 'agent_1': -26.635485754669688, 'agent_2': -26.52548575466969, 'agent_3': -26.56048575466969} at episode 1650, timestep 41250, epsilon 0.1
# running rewards: {'agent_0': -26.621936860236996, 'agent_1': -26.541936860236998, 'agent_2': -26.531936860236996, 'agent_3': -26.421936860236997} at episode 1700, timestep 42500, epsilon 0.1
# running rewards: {'agent_0': -26.183008583054484, 'agent_1': -26.158008583054485, 'agent_2': -26.048008583054482, 'agent_3': -25.893008583054485} at episode 1750, timestep 43750, epsilon 0.1
# running rewards: {'agent_0': -25.57989702396842, 'agent_1': -25.81989702396842, 'agent_2': -25.56489702396842, 'agent_3': -25.38489702396842} at episode 1800, timestep 45000, epsilon 0.1
# running rewards: {'agent_0': -25.123099848643474, 'agent_1': -25.343099848643472, 'agent_2': -25.183099848643472, 'agent_3': -24.863099848643472} at episode 1850, timestep 46250, epsilon 0.1
# running rewards: {'agent_0': -24.895502176290876, 'agent_1': -25.02550217629087, 'agent_2': -25.03050217629087, 'agent_3': -24.690502176290874} at episode 1900, timestep 47500, epsilon 0.1
# running rewards: {'agent_0': -25.58655813512706, 'agent_1': -25.75655813512706, 'agent_2': -25.701558135127062, 'agent_3': -25.53155813512706} at episode 1950, timestep 48750, epsilon 0.1
# running rewards: {'agent_0': -26.059307104557274, 'agent_1': -26.154307104557276, 'agent_2': -25.919307104557273, 'agent_3': -25.934307104557274} at episode 2000, timestep 50000, epsilon 0.1
# running rewards: {'agent_0': -25.48760379720569, 'agent_1': -25.487603797205683, 'agent_2': -25.342603797205687, 'agent_3': -25.36260379720569} at episode 2050, timestep 51250, epsilon 0.1
# running rewards: {'agent_0': -25.328219923049055, 'agent_1': -25.278219923049054, 'agent_2': -25.233219923049056, 'agent_3': -25.213219923049056} at episode 2100, timestep 52500, epsilon 0.1
# running rewards: {'agent_0': -25.610470016605817, 'agent_1': -25.515470016605818, 'agent_2': -25.51047001660582, 'agent_3': -25.535470016605817} at episode 2150, timestep 53750, epsilon 0.1
# running rewards: {'agent_0': -25.84843378041476, 'agent_1': -25.763433780414754, 'agent_2': -25.933433780414752, 'agent_3': -25.838433780414757} at episode 2200, timestep 55000, epsilon 0.1
# running rewards: {'agent_0': -25.509772714719364, 'agent_1': -25.579772714719365, 'agent_2': -25.744772714719364, 'agent_3': -25.564772714719364} at episode 2250, timestep 56250, epsilon 0.1
# running rewards: {'agent_0': -25.968681752482265, 'agent_1': -25.958681752482267, 'agent_2': -26.028681752482267, 'agent_3': -25.998681752482266} at episode 2300, timestep 57500, epsilon 0.1
# running rewards: {'agent_0': -26.84996486635932, 'agent_1': -26.78996486635932, 'agent_2': -26.77496486635932, 'agent_3': -26.744964866359318} at episode 2350, timestep 58750, epsilon 0.1
# running rewards: {'agent_0': -26.739323162438023, 'agent_1': -26.754323162438027, 'agent_2': -26.79932316243802, 'agent_3': -26.794323162438022} at episode 2400, timestep 60000, epsilon 0.1
# running rewards: {'agent_0': -26.788408148512428, 'agent_1': -26.693408148512425, 'agent_2': -26.828408148512427, 'agent_3': -26.893408148512425} at episode 2450, timestep 61250, epsilon 0.1
# running rewards: {'agent_0': -26.303626456195676, 'agent_1': -26.19862645619568, 'agent_2': -26.32362645619568, 'agent_3': -26.328626456195675} at episode 2500, timestep 62500, epsilon 0.1
# running rewards: {'agent_0': -25.39869630385739, 'agent_1': -25.283696303857386, 'agent_2': -25.323696303857385, 'agent_3': -25.278696303857387} at episode 2550, timestep 63750, epsilon 0.1
# running rewards: {'agent_0': -24.482446794404233, 'agent_1': -24.567446794404233, 'agent_2': -24.447446794404232, 'agent_3': -24.45244679440423} at episode 2600, timestep 65000, epsilon 0.1
# running rewards: {'agent_0': -24.63416322554313, 'agent_1': -24.769163225543128, 'agent_2': -24.68416322554313, 'agent_3': -24.70916322554313} at episode 2650, timestep 66250, epsilon 0.1
# running rewards: {'agent_0': -25.585234064163206, 'agent_1': -25.635234064163214, 'agent_2': -25.58523406416321, 'agent_3': -25.44523406416321} at episode 2700, timestep 67500, epsilon 0.1
# running rewards: {'agent_0': -25.38531865185766, 'agent_1': -25.31531865185766, 'agent_2': -25.265318651857662, 'agent_3': -25.28531865185766} at episode 2750, timestep 68750, epsilon 0.1
# running rewards: {'agent_0': -24.894646190522998, 'agent_1': -24.729646190523, 'agent_2': -24.654646190523, 'agent_3': -24.909646190523} at episode 2800, timestep 70000, epsilon 0.1
# running rewards: {'agent_0': -25.097097967527926, 'agent_1': -25.082097967527925, 'agent_2': -25.052097967527924, 'agent_3': -25.047097967527925} at episode 2850, timestep 71250, epsilon 0.1
# running rewards: {'agent_0': -25.632807770135837, 'agent_1': -25.602807770135836, 'agent_2': -25.71780777013584, 'agent_3': -25.477807770135836} at episode 2900, timestep 72500, epsilon 0.1
# running rewards: {'agent_0': -26.66791220288024, 'agent_1': -26.51791220288024, 'agent_2': -26.68291220288024, 'agent_3': -26.57291220288024} at episode 2950, timestep 73750, epsilon 0.1
# running rewards: {'agent_0': -26.389090716581787, 'agent_1': -26.449090716581786, 'agent_2': -26.334090716581787, 'agent_3': -26.544090716581785} at episode 3000, timestep 75000, epsilon 0.1
# running rewards: {'agent_0': -25.88283495454786, 'agent_1': -26.032834954547862, 'agent_2': -25.76783495454786, 'agent_3': -25.98783495454786} at episode 3050, timestep 76250, epsilon 0.1
# running rewards: {'agent_0': -26.19768831474497, 'agent_1': -26.31768831474497, 'agent_2': -26.077688314744968, 'agent_3': -26.13768831474497} at episode 3100, timestep 77500, epsilon 0.1
# running rewards: {'agent_0': -25.9187582376156, 'agent_1': -26.0087582376156, 'agent_2': -25.868758237615598, 'agent_3': -25.858758237615596} at episode 3150, timestep 78750, epsilon 0.1
# running rewards: {'agent_0': -25.827943940584895, 'agent_1': -25.842943940584895, 'agent_2': -25.937943940584898, 'agent_3': -25.912943940584896} at episode 3200, timestep 80000, epsilon 0.1
# running rewards: {'agent_0': -25.989876501759003, 'agent_1': -26.004876501759004, 'agent_2': -26.184876501759003, 'agent_3': -26.119876501759006} at episode 3250, timestep 81250, epsilon 0.1
# running rewards: {'agent_0': -25.810790234163004, 'agent_1': -25.780790234163007, 'agent_2': -25.950790234163005, 'agent_3': -25.790790234163005} at episode 3300, timestep 82500, epsilon 0.1
# running rewards: {'agent_0': -25.297547580193633, 'agent_1': -25.442547580193633, 'agent_2': -25.38254758019363, 'agent_3': -25.457547580193634} at episode 3350, timestep 83750, epsilon 0.1
# running rewards: {'agent_0': -25.70870161295703, 'agent_1': -25.81370161295703, 'agent_2': -25.963701612957028, 'agent_3': -25.878701612957034} at episode 3400, timestep 85000, epsilon 0.1
# running rewards: {'agent_0': -26.644380297031176, 'agent_1': -26.694380297031174, 'agent_2': -26.909380297031177, 'agent_3': -26.779380297031175} at episode 3450, timestep 86250, epsilon 0.1
# running rewards: {'agent_0': -25.94703172264776, 'agent_1': -26.05203172264776, 'agent_2': -26.122031722647762, 'agent_3': -26.327031722647767} at episode 3500, timestep 87500, epsilon 0.1
# running rewards: {'agent_0': -25.653026840538487, 'agent_1': -25.653026840538487, 'agent_2': -25.873026840538486, 'agent_3': -25.913026840538485} at episode 3550, timestep 88750, epsilon 0.1
# running rewards: {'agent_0': -26.168681825624045, 'agent_1': -26.053681825624043, 'agent_2': -26.263681825624044, 'agent_3': -26.168681825624045} at episode 3600, timestep 90000, epsilon 0.1
# running rewards: {'agent_0': -25.66118462895526, 'agent_1': -25.45118462895526, 'agent_2': -25.63118462895526, 'agent_3': -25.691184628955256} at episode 3650, timestep 91250, epsilon 0.1
# running rewards: {'agent_0': -24.770914503767486, 'agent_1': -24.610914503767482, 'agent_2': -24.69091450376748, 'agent_3': -24.78091450376748} at episode 3700, timestep 92500, epsilon 0.1
# running rewards: {'agent_0': -24.498630911993008, 'agent_1': -24.48863091199301, 'agent_2': -24.66863091199301, 'agent_3': -24.62863091199301} at episode 3750, timestep 93750, epsilon 0.1
# running rewards: {'agent_0': -24.339991761372747, 'agent_1': -24.354991761372748, 'agent_2': -24.639991761372748, 'agent_3': -24.554991761372747} at episode 3800, timestep 95000, epsilon 0.1
# running rewards: {'agent_0': -25.04729157024266, 'agent_1': -25.04229157024266, 'agent_2': -25.162291570242658, 'agent_3': -25.07729157024266} at episode 3850, timestep 96250, epsilon 0.1
# running rewards: {'agent_0': -25.324103160389733, 'agent_1': -25.344103160389736, 'agent_2': -25.449103160389733, 'agent_3': -25.449103160389733} at episode 3900, timestep 97500, epsilon 0.1
# running rewards: {'agent_0': -24.41621181219232, 'agent_1': -24.38121181219232, 'agent_2': -24.566211812192318, 'agent_3': -24.52121181219232} at episode 3950, timestep 98750, epsilon 0.1
# running rewards: {'agent_0': -24.23303168343009, 'agent_1': -24.22803168343009, 'agent_2': -24.358031683430095, 'agent_3': -24.223031683430094} at episode 4000, timestep 100000, epsilon 0.1
# running rewards: {'agent_0': -24.894914112885534, 'agent_1': -24.889914112885535, 'agent_2': -24.959914112885535, 'agent_3': -24.89491411288554} at episode 4050, timestep 101250, epsilon 0.1
# running rewards: {'agent_0': -24.96661758465384, 'agent_1': -24.906617584653837, 'agent_2': -24.951617584653835, 'agent_3': -24.82161758465384} at episode 4100, timestep 102500, epsilon 0.1
# running rewards: {'agent_0': -24.686349601246594, 'agent_1': -24.656349601246593, 'agent_2': -24.581349601246597, 'agent_3': -24.5213496012466} at episode 4150, timestep 103750, epsilon 0.1
# running rewards: {'agent_0': -25.74528435395207, 'agent_1': -25.64528435395207, 'agent_2': -25.655284353952066, 'agent_3': -25.68528435395207} at episode 4200, timestep 105000, epsilon 0.1
# running rewards: {'agent_0': -25.722398506222493, 'agent_1': -25.587398506222495, 'agent_2': -25.712398506222495, 'agent_3': -25.727398506222492} at episode 4250, timestep 106250, epsilon 0.1
# running rewards: {'agent_0': -25.584695336007485, 'agent_1': -25.424695336007485, 'agent_2': -25.559695336007486, 'agent_3': -25.489695336007486} at episode 4300, timestep 107500, epsilon 0.1
# running rewards: {'agent_0': -25.67900530294487, 'agent_1': -25.554005302944866, 'agent_2': -25.59900530294487, 'agent_3': -25.484005302944876} at episode 4350, timestep 108750, epsilon 0.1
# running rewards: {'agent_0': -25.158697703235063, 'agent_1': -25.163697703235062, 'agent_2': -25.18869770323506, 'agent_3': -25.073697703235062} at episode 4400, timestep 110000, epsilon 0.1
# running rewards: {'agent_0': -25.271986043835742, 'agent_1': -25.25698604383574, 'agent_2': -25.33198604383574, 'agent_3': -25.376986043835743} at episode 4450, timestep 111250, epsilon 0.1
# running rewards: {'agent_0': -24.903902353464165, 'agent_1': -24.893902353464163, 'agent_2': -24.808902353464163, 'agent_3': -24.968902353464163} at episode 4500, timestep 112500, epsilon 0.1
# running rewards: {'agent_0': -24.47070886566893, 'agent_1': -24.380708865668936, 'agent_2': -24.47570886566893, 'agent_3': -24.43570886566893} at episode 4550, timestep 113750, epsilon 0.1
# running rewards: {'agent_0': -25.72962224330662, 'agent_1': -25.634622243306616, 'agent_2': -25.774622243306617, 'agent_3': -25.679622243306618} at episode 4600, timestep 115000, epsilon 0.1
# running rewards: {'agent_0': -25.781166576357414, 'agent_1': -25.871166576357414, 'agent_2': -25.801166576357414, 'agent_3': -25.781166576357414} at episode 4650, timestep 116250, epsilon 0.1
# running rewards: {'agent_0': -24.937641245484148, 'agent_1': -25.047641245484147, 'agent_2': -24.912641245484146, 'agent_3': -24.942641245484147} at episode 4700, timestep 117500, epsilon 0.1
# running rewards: {'agent_0': -25.868458778489234, 'agent_1': -25.833458778489234, 'agent_2': -25.803458778489233, 'agent_3': -25.688458778489235} at episode 4750, timestep 118750, epsilon 0.1
# running rewards: {'agent_0': -25.553500768366394, 'agent_1': -25.533500768366395, 'agent_2': -25.563500768366392, 'agent_3': -25.553500768366394} at episode 4800, timestep 120000, epsilon 0.1
# running rewards: {'agent_0': -25.36821342812924, 'agent_1': -25.373213428129244, 'agent_2': -25.343213428129243, 'agent_3': -25.558213428129243} at episode 4850, timestep 121250, epsilon 0.1
# running rewards: {'agent_0': -25.542075059571435, 'agent_1': -25.437075059571434, 'agent_2': -25.487075059571435, 'agent_3': -25.432075059571435} at episode 4900, timestep 122500, epsilon 0.1
# running rewards: {'agent_0': -24.785249974345426, 'agent_1': -24.760249974345424, 'agent_2': -24.820249974345426, 'agent_3': -24.775249974345424} at episode 4950, timestep 123750, epsilon 0.1
# running rewards: {'agent_0': -25.14955884483857, 'agent_1': -25.13955884483857, 'agent_2': -25.24955884483857, 'agent_3': -25.37955884483857} at episode 5000, timestep 125000, epsilon 0.1

# %%
# Training Plots (for Debugging)
env.reset()  # Reset env to make sure agent list isn't empty

for agent in env.agents:
    # Raw Reward
    plt.title(f"{agent}: Reward / Episode")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.plot(np.arange(len(episode_reward_history[agent])), episode_reward_history[agent])
    plt.show()

# Rolling Average Reward:
def moving_average(x, w):
    # Source: https://stackoverflow.com/a/54628145
    return np.convolve(x, np.ones(w), 'valid') / w

for agent in env.agents:
    rolling_means = moving_average(episode_reward_history[agent], 100)

    # Rolling Average
    plt.title(f"{agent}: Rolling Mean Reward")
    plt.xlabel("Episode") 
    plt.ylabel("Average Total Reward (Last 100 Episodes)")
    plt.plot(np.arange(len(rolling_means)) + 100, rolling_means)
    plt.show()

for agent in env.agents:
    # Loss Trend
    plt.title(f"{agent}: Loss History")
    plt.xlabel("Training Step") 
    plt.ylabel("Loss")
    plt.plot(np.arange(len(loss_history[agent])), loss_history[agent])
    plt.show()

for agent in env.agents:
    # Avg. Max Q Trend
    plt.title(f"{agent}: Avg. Max Q Value History")
    plt.xlabel("Episode") 
    plt.ylabel("Avg. Max Q Value")
    plt.plot(np.arange(len(avg_max_Q_history[agent])), avg_max_Q_history[agent])
    plt.show()

# %% [markdown]
# ## Final Evaluation

# %%
def eval_greedy_model(env, models):
    env.reset()  # Reset env to make sure agent list isn't empty

    # Tracking values
    final_eval_rewards = {agent: [] for agent in env.agents}
    
    #update to 500 for gif looping
    for episode in range(500):
        observations, _ = env.reset()
        episode_rewards = {agent: 0 for agent in env.agents}

        while env.agents:
            actions = select_actions(env, observations, models, epsilon=0)

            # Follow selected actions
            observations_next, rewards, _, _, _ = env.step(actions)
            
            # Save action results
            for agent in rewards.keys():
                episode_rewards[agent] += rewards[agent]

            observations = observations_next

        # Record tracking statistics:
        for agent, episode_reward in episode_rewards.items():
            final_eval_rewards[agent].append(episode_reward)


    avg_greedy_reward = {
        agent: np.mean(final_eval_reward)
        for agent, final_eval_reward in final_eval_rewards.items()
    }

    return avg_greedy_reward, final_eval_rewards

# %%
avg_greedy_reward, final_eval_rewards = eval_greedy_model(env, models)

print(avg_greedy_reward)

env.reset()  # Reset env to make sure agent list isn't empty

for agent in env.agents:
    # Raw Reward
    plt.title(f"{agent}: Reward / Episode")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.plot(np.arange(len(final_eval_rewards[agent])), final_eval_rewards[agent])
    plt.show()
# Out:
# {'agent_0': -25.666501931182424, 'agent_1': -25.736501931182424, 'agent_2': -25.705501931182425, 'agent_3': -25.759501931182424}

# %%
# Visualize full episode
# MUST MATCH MODEL TRAINING
rendered_env = simple_spread_comms.parallel_env(n_agents = 4, n_landmarks = 4, comm_mode=2, render_mode="rgb_array")
frames = []

observations, _ = rendered_env.reset()
frames.append(rendered_env.render())

while rendered_env.agents:
    # this is where you would insert your policy
    actions = select_actions(rendered_env, observations, models, epsilon=0)

    observations, _, _, _, _ = rendered_env.step(actions)
    frames.append(rendered_env.render())

rendered_env.close()

imageio.mimwrite(
    "rendered_episode.gif",
    frames,
    loop=0  # Infinite loop gif
)
