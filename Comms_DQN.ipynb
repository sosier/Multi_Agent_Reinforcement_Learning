# %% [markdown]
# # Communication Simple Spread - DQN

# %%
# %load_ext autoreload
# %autoreload 2

from collections import namedtuple
import imageio
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import simple_spread_comms

# Set up matplotlib:
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# Detect if GPU is available:
DEVICE = torch.device(
    "mps" if torch.backends.mps.is_available()
    else (
        "cuda" if torch.cuda.is_available()
        else "cpu"
    )
)

# Global params:
GAMMA = 0.99  # < 1 to encourage prioritization of immediate rewards

# %% [markdown]
# ## Set Up Environment

# %%
# Set up environment
# N = 2
env = simple_spread_comms.parallel_env(n_agents = 2, n_landmarks = 3, comm_mode=4)

observations, _ = env.reset()
observation_dim = observations["agent_0"].shape[0]
num_actions = env.action_space("agent_0").n

print("num_agents = ", env.num_agents, env.agents)
print(f"{num_actions=}")
print(f"{observation_dim=}")

observations
# Out:
# num_agents =  2 ['agent_0', 'agent_1']
# num_actions=5
# observation_dim=13
# {'agent_0': array([ 0.        ,  0.        ,  0.7413052 , -0.9791966 , -1.4780195 ,
#          0.8215885 , -1.0626831 ,  1.8534459 , -1.3742648 ,  0.55758584,
#         -0.20237991,  1.394355  ,  0.        ], dtype=float32),
#  'agent_1': array([ 0.        ,  0.        ,  0.5389253 ,  0.41515848, -1.2756397 ,
#         -0.57276654, -0.8603032 ,  0.4590908 , -1.1718849 , -0.8367692 ,
#          0.20237991, -1.394355  ,  0.        ], dtype=float32)}

# %% [markdown]
# ## Helpers

# %%
class DQN(nn.Module):
    def __init__(
            self,
            input_dim=observation_dim,
            layers=[],
            output_dim=num_actions,
            activation_function="ReLU",
            loss_function="huber_loss",
            **kwargs
        ):
        super().__init__()

        # Validate Inputs:
        assert len(layers) > 0

        if type(activation_function) == str:
            assert(activation_function in nn.__dict__), (
                "activation_function must be one of the activation functions " +
                "available in the torch.nn module, e.g. 'ReLU'"
            )
            activation_function = nn.__dict__[activation_function]
        
        if type(loss_function) == str:
            assert(loss_function in F.__dict__), (
                "loss_function must be one of the loss functions " +
                "available in the torch.nn.functional module, e.g. 'cross_entropy'"
            )
            loss_function = F.__dict__[loss_function]

        # ------------------------------
        # Actually Initialize the Model:
        # ------------------------------
        self.layers = nn.ModuleList()

        # Hidden MLP Layers:
        for i, layer_size in enumerate(layers):
            if i == 0:
                layer_in = input_dim
            else:
                layer_in = layers[i - 1]

            layer = nn.Sequential(
                nn.Linear(layer_in, layer_size),
                activation_function()
            )
            self.layers.append(layer)

        # Final Fully Connected Output Layer:
        self.layers.append(nn.Linear(layers[-1], output_dim))
        
        # Loss:
        self.loss_function = loss_function

    def copy_weights(self, other_model):
        self.load_state_dict(other_model.state_dict())

    def forward(self, X, targets=None):
        for layer in self.layers:
            X = layer(X)

        # Final layer's output is the logits:
        logits = X

        if targets is not None:
            loss = self.loss_function(logits, targets)
            return logits, loss
        else:
            return logits

# Models objects for holding all the models for an agent:
Models = namedtuple("Models", ["main", "target"])

def _initialize_models(model_size):
    # Model used for selecting actions (principal)
    model = DQN(layers=[model_size] * 2).to(DEVICE)
    
    # Then create the target model. This will periodically be copied from the principal network 
    target_model = DQN(layers=[model_size] * 2).to(DEVICE)

    # Make sure models are initialized identically:
    target_model.copy_weights(model)

    return Models(model, target_model)

def initialize_models(env, model_size):
    env.reset()  # Reset env to make sure agent list isn't empty
    return {agent: _initialize_models(model_size) for agent in env.agents}

def select_actions(env, observations, models, epsilon):
    # Epsilon greedy
    if np.random.random() < epsilon:
        # Take random actions:
        actions = {agent: env.action_space(agent).sample() for agent in env.agents}
    else:
        # Predict action Q-values
        # From environment observations
        actions = {}
        for agent, model in models.items():
            model.main.eval()
            actions[agent] = model.main(
                # Observation (state) as tensor
                torch.tensor(observations[agent]).to(DEVICE)
            ).argmax(dim=-1).item()
    
    return actions

class ReplayBuffer():
    def __init__(
            self,
            max_size,
            state_dim=observation_dim,
            action_dim=1,
            reward_dim=1,
        ):
        self.history = []
        self.max_size = max_size
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.reward_dim = reward_dim
    
    @property
    def size(self):
        return len(self.history)
    
    def states(self, i):
        return self.history[i, :self.state_dim]

    def actions(self, i):
        return self.history[i, self.state_dim:(self.state_dim + self.action_dim)]

    def rewards(self, i):
        return self.history[
            i,
            (self.state_dim + self.action_dim)
            :(self.state_dim + self.action_dim + self.reward_dim)
        ]

    def state_nexts(self, i):
        return self.history[i, -self.state_dim:]
    
    def store(self, state, action, reward, state_next):
        if self.action_dim == 1: action = [action]
        if self.reward_dim == 1: reward = [reward]

        SARS = np.concatenate(
            [state, action, reward, state_next],
            dtype="float32"
        ).reshape(1, -1)

        if self.size == 0:
            self.history = SARS
        else:
            self.history = np.concatenate([self.history, SARS], axis=0)
    
        # Don't let the memory grow beyond the limit
        if self.size > self.max_size:
            self.history = self.history[1:]

    def sample(self, n):
        #  Sample a set of batch_size memories from the history
        sample_ids = np.random.choice(
            np.arange(self.size), size=n, replace=False
        )

        states = torch.tensor(self.states(sample_ids)).to(DEVICE)
        actions = torch.tensor(self.actions(sample_ids)).to(DEVICE)
        rewards = torch.tensor(self.rewards(sample_ids)).to(DEVICE)
        state_nexts = torch.tensor(self.state_nexts(sample_ids)).to(DEVICE)

        return states, actions, rewards, state_nexts

def train_one_step(models, memories, optimizers, batch_size=128):
    losses = {}

    for agent, model in models.items():
        #  Sample a set of batch_size memories from the history
        states, actions, rewards, state_nexts = memories[agent].sample(batch_size)

        # Create for the sample states the targets (r+gamma * max Q(...) )
        model.target.eval()
        Q_next_state = model.target(state_nexts)
        Q_targets = rewards + GAMMA * Q_next_state.max(axis=-1).values.view(-1, 1)

        # Q values to train:
        model.main.train()
        Q_values = model.main(states)
        # Pluck out the relevant actions only
        Q_of_actions = Q_values.gather(1, actions.to(int))

        # Calculate loss and perform optimization step:
        loss = model.main.loss_function(Q_of_actions, Q_targets)
        optimizers[agent].zero_grad()
        loss.backward()
        optimizers[agent].step()

        losses[agent] = loss.item()
    
    return losses

# Build validation dateset of held out states for use in tracking avg. max Q as
# a training validation / debugging metric:
def generate_validation_data(env=env, n=100):
    env.reset()  # Reset env to make sure agent list isn't empty
    validation_data = {agent: [] for agent in env.agents}

    for episode in range(n):
        observations, _ = env.reset()

        while env.agents:
            for agent in env.agents:
                validation_data[agent].append(observations[agent])

            # Take random actions:
            actions = {agent: env.action_space(agent).sample() for agent in env.agents}
            # Follow selected actions:
            observations, _, _, _, _ = env.step(actions)

    env.reset()  # Reset env to make sure agent list isn't empty
    validation_data = {
        agent: torch.tensor(np.array(validation_data[agent])).to(DEVICE)
        for agent in env.agents
    }
    return validation_data

def calc_avg_max_Q(models, validation_data):
    avg_max_Qs = {}
    for agent, model in models.items():
        model.main.eval()
        avg_max_Qs[agent] =\
            model.main(validation_data[agent]).max(axis=-1).values.mean().item()
    
    return avg_max_Qs

# %% [markdown]
# ## Validation Set Up

# %%
validation_data = generate_validation_data(env=env, n=100)

# %% [markdown]
# ## Training Loop

# %%
# ==============================================================================
# KEY PARAMS:
model_size = 128
batch_size = 128
learning_rate = 5e-4
max_episodes = 5000
max_memory = 10000  # Replay memory size
# how often to train your model - this allows you to speed up learning
# by not performing in every iteration learning. See also refernece paper
# you can set this value to other values like 1 as well to learn every time 
update_after_actions = 4
target_update_every = 1000  # How often to update the target network
epsilon = 0.1
# ==============================================================================

# Initialize models:
models = initialize_models(env, model_size)
optimizers = {
    agent: optim.Adam(model.main.parameters(), lr=learning_rate)
    for agent, model in models.items()
}

# Our Experience Replay memory (state, action, reward, next state)
env.reset()  # Reset env to make sure agent list isn't empty
memories = {agent: ReplayBuffer(max_memory) for agent in env.agents}
episode_reward_history = {agent: [] for agent in env.agents}
loss_history = {agent: [] for agent in env.agents}
avg_max_Q_history = {agent: [] for agent in env.agents}

# Tracking values
running_rewards = {agent: 0 for agent in env.agents}
episode_count = 0
timestep_count = 0

# Training Loop
for episode in range(max_episodes):
    observations, _ = env.reset()
    episode_rewards = {agent: 0 for agent in env.agents}

    while env.agents:
        timestep_count += 1
        actions = select_actions(env, observations, models, epsilon)

        # Follow selected actions
        observations_next, rewards, _, _, _ = env.step(actions)
        
        # Save action results
        for agent in rewards.keys():
            episode_rewards[agent] += rewards[agent]

            # Save action/states and other information in replay buffer
            memories[agent].store(
                observations[agent],
                actions[agent],
                rewards[agent],
                observations_next[agent]
            )

        observations = observations_next

        # Update every Xth frame to speed up (optional)
        # and if you have sufficient history
        if timestep_count % update_after_actions == 0 and timestep_count > batch_size:
            losses = train_one_step(models, memories, optimizers, batch_size)
            for agent, loss in losses.items():
                loss_history[agent].append(loss)

        if timestep_count % target_update_every == 0:
            # Update the the target network with new weights
            for model in models.values():
                model.target.copy_weights(model.main)

    # Record tracking statistics:
    for agent, episode_reward in episode_rewards.items():
        episode_reward_history[agent].append(episode_reward)
    
    for agent, avg_max_Q in calc_avg_max_Q(models, validation_data).items():
        avg_max_Q_history[agent].append(avg_max_Q)

    episode_count += 1

    # Logging:
    if episode_count % 50 == 0:
        # Log details
        # average reward of last 100:
        running_rewards = {
            agent: np.mean(episode_reward_history[agent][-100:])
            for agent in running_rewards.keys()
        }
        template = "running rewards: {} at episode {}, timestep {}, epsilon {}"
        print(template.format(running_rewards, episode_count, timestep_count, epsilon))
# Out:
# running rewards: {'agent_0': -39.91921198116324, 'agent_1': -39.91921198116324} at episode 50, timestep 1250, epsilon 0.1
# running rewards: {'agent_0': -35.30846513362352, 'agent_1': -35.30846513362352} at episode 100, timestep 2500, epsilon 0.1
# running rewards: {'agent_0': -31.474087014227358, 'agent_1': -31.474087014227358} at episode 150, timestep 3750, epsilon 0.1
# running rewards: {'agent_0': -29.287653041644038, 'agent_1': -29.287653041644038} at episode 200, timestep 5000, epsilon 0.1
# running rewards: {'agent_0': -26.15731172325046, 'agent_1': -26.15731172325046} at episode 250, timestep 6250, epsilon 0.1
# running rewards: {'agent_0': -25.57473398097243, 'agent_1': -25.57473398097243} at episode 300, timestep 7500, epsilon 0.1
# running rewards: {'agent_0': -25.182972161854295, 'agent_1': -25.182972161854295} at episode 350, timestep 8750, epsilon 0.1
# running rewards: {'agent_0': -25.277886275319347, 'agent_1': -25.277886275319347} at episode 400, timestep 10000, epsilon 0.1
# running rewards: {'agent_0': -24.455624736204282, 'agent_1': -24.455624736204282} at episode 450, timestep 11250, epsilon 0.1
# running rewards: {'agent_0': -22.636278530751817, 'agent_1': -22.636278530751817} at episode 500, timestep 12500, epsilon 0.1
# running rewards: {'agent_0': -22.434627247042254, 'agent_1': -22.434627247042254} at episode 550, timestep 13750, epsilon 0.1
# running rewards: {'agent_0': -22.102532712629696, 'agent_1': -22.102532712629696} at episode 600, timestep 15000, epsilon 0.1
# running rewards: {'agent_0': -21.69370835523275, 'agent_1': -21.69370835523275} at episode 650, timestep 16250, epsilon 0.1
# running rewards: {'agent_0': -22.112974946023083, 'agent_1': -22.112974946023083} at episode 700, timestep 17500, epsilon 0.1
# running rewards: {'agent_0': -21.442760206865145, 'agent_1': -21.442760206865145} at episode 750, timestep 18750, epsilon 0.1
# running rewards: {'agent_0': -21.36146203281141, 'agent_1': -21.36146203281141} at episode 800, timestep 20000, epsilon 0.1
# running rewards: {'agent_0': -21.07860939677799, 'agent_1': -21.07860939677799} at episode 850, timestep 21250, epsilon 0.1
# running rewards: {'agent_0': -21.571055894444353, 'agent_1': -21.571055894444353} at episode 900, timestep 22500, epsilon 0.1
# running rewards: {'agent_0': -22.20623415682154, 'agent_1': -22.20623415682154} at episode 950, timestep 23750, epsilon 0.1
# running rewards: {'agent_0': -21.366648560874527, 'agent_1': -21.366648560874527} at episode 1000, timestep 25000, epsilon 0.1
# running rewards: {'agent_0': -21.446601118654357, 'agent_1': -21.446601118654357} at episode 1050, timestep 26250, epsilon 0.1
# running rewards: {'agent_0': -21.467480135449883, 'agent_1': -21.467480135449883} at episode 1100, timestep 27500, epsilon 0.1
# running rewards: {'agent_0': -21.4083928914976, 'agent_1': -21.4083928914976} at episode 1150, timestep 28750, epsilon 0.1
# running rewards: {'agent_0': -21.844057611137856, 'agent_1': -21.844057611137856} at episode 1200, timestep 30000, epsilon 0.1
# running rewards: {'agent_0': -20.799819925733477, 'agent_1': -20.799819925733477} at episode 1250, timestep 31250, epsilon 0.1
# running rewards: {'agent_0': -20.168346321630246, 'agent_1': -20.168346321630246} at episode 1300, timestep 32500, epsilon 0.1
# running rewards: {'agent_0': -20.942874837164396, 'agent_1': -20.942874837164396} at episode 1350, timestep 33750, epsilon 0.1
# running rewards: {'agent_0': -21.140803811710157, 'agent_1': -21.140803811710157} at episode 1400, timestep 35000, epsilon 0.1
# running rewards: {'agent_0': -21.156405512691045, 'agent_1': -21.156405512691045} at episode 1450, timestep 36250, epsilon 0.1
# running rewards: {'agent_0': -20.46167768577469, 'agent_1': -20.46167768577469} at episode 1500, timestep 37500, epsilon 0.1
# running rewards: {'agent_0': -19.922550158716597, 'agent_1': -19.922550158716597} at episode 1550, timestep 38750, epsilon 0.1
# running rewards: {'agent_0': -19.930448271658637, 'agent_1': -19.930448271658637} at episode 1600, timestep 40000, epsilon 0.1
# running rewards: {'agent_0': -19.551823118702057, 'agent_1': -19.551823118702057} at episode 1650, timestep 41250, epsilon 0.1
# running rewards: {'agent_0': -19.98711647769254, 'agent_1': -19.98711647769254} at episode 1700, timestep 42500, epsilon 0.1
# running rewards: {'agent_0': -19.6455299664011, 'agent_1': -19.6455299664011} at episode 1750, timestep 43750, epsilon 0.1
# running rewards: {'agent_0': -18.477718574216258, 'agent_1': -18.477718574216258} at episode 1800, timestep 45000, epsilon 0.1
# running rewards: {'agent_0': -19.697967345224896, 'agent_1': -19.697967345224896} at episode 1850, timestep 46250, epsilon 0.1
# running rewards: {'agent_0': -19.671446039101777, 'agent_1': -19.671446039101777} at episode 1900, timestep 47500, epsilon 0.1
# running rewards: {'agent_0': -19.047147758946544, 'agent_1': -19.047147758946544} at episode 1950, timestep 48750, epsilon 0.1
# running rewards: {'agent_0': -19.823759723933122, 'agent_1': -19.823759723933122} at episode 2000, timestep 50000, epsilon 0.1
# running rewards: {'agent_0': -19.560217465024067, 'agent_1': -19.560217465024067} at episode 2050, timestep 51250, epsilon 0.1
# running rewards: {'agent_0': -20.161164485829428, 'agent_1': -20.161164485829428} at episode 2100, timestep 52500, epsilon 0.1
# running rewards: {'agent_0': -21.677049868767536, 'agent_1': -21.677049868767536} at episode 2150, timestep 53750, epsilon 0.1
# running rewards: {'agent_0': -21.29787670757118, 'agent_1': -21.29787670757118} at episode 2200, timestep 55000, epsilon 0.1
# running rewards: {'agent_0': -19.290947134664048, 'agent_1': -19.290947134664048} at episode 2250, timestep 56250, epsilon 0.1
# running rewards: {'agent_0': -18.645335840494386, 'agent_1': -18.645335840494386} at episode 2300, timestep 57500, epsilon 0.1
# running rewards: {'agent_0': -18.29486616723614, 'agent_1': -18.29486616723614} at episode 2350, timestep 58750, epsilon 0.1
# running rewards: {'agent_0': -18.1416393528085, 'agent_1': -18.1416393528085} at episode 2400, timestep 60000, epsilon 0.1
# running rewards: {'agent_0': -19.036816756341068, 'agent_1': -19.036816756341068} at episode 2450, timestep 61250, epsilon 0.1
# running rewards: {'agent_0': -19.936197030846298, 'agent_1': -19.936197030846298} at episode 2500, timestep 62500, epsilon 0.1
# running rewards: {'agent_0': -19.82401789507593, 'agent_1': -19.82401789507593} at episode 2550, timestep 63750, epsilon 0.1
# running rewards: {'agent_0': -18.82831597209828, 'agent_1': -18.82831597209828} at episode 2600, timestep 65000, epsilon 0.1
# running rewards: {'agent_0': -18.90890734091391, 'agent_1': -18.90890734091391} at episode 2650, timestep 66250, epsilon 0.1
# running rewards: {'agent_0': -19.06104153436943, 'agent_1': -19.06104153436943} at episode 2700, timestep 67500, epsilon 0.1
# running rewards: {'agent_0': -19.03885268170157, 'agent_1': -19.03885268170157} at episode 2750, timestep 68750, epsilon 0.1
# running rewards: {'agent_0': -19.569051636891366, 'agent_1': -19.569051636891366} at episode 2800, timestep 70000, epsilon 0.1
# running rewards: {'agent_0': -19.4753916029015, 'agent_1': -19.4753916029015} at episode 2850, timestep 71250, epsilon 0.1
# running rewards: {'agent_0': -18.53553747344661, 'agent_1': -18.53553747344661} at episode 2900, timestep 72500, epsilon 0.1
# running rewards: {'agent_0': -18.745665930658866, 'agent_1': -18.745665930658866} at episode 2950, timestep 73750, epsilon 0.1
# running rewards: {'agent_0': -19.309072179919863, 'agent_1': -19.309072179919863} at episode 3000, timestep 75000, epsilon 0.1
# running rewards: {'agent_0': -19.16246910257228, 'agent_1': -19.16246910257228} at episode 3050, timestep 76250, epsilon 0.1
# running rewards: {'agent_0': -19.855968557911435, 'agent_1': -19.855968557911435} at episode 3100, timestep 77500, epsilon 0.1
# running rewards: {'agent_0': -19.40089200364832, 'agent_1': -19.40089200364832} at episode 3150, timestep 78750, epsilon 0.1
# running rewards: {'agent_0': -18.8574595561934, 'agent_1': -18.8574595561934} at episode 3200, timestep 80000, epsilon 0.1
# running rewards: {'agent_0': -18.75546043280074, 'agent_1': -18.75546043280074} at episode 3250, timestep 81250, epsilon 0.1
# running rewards: {'agent_0': -18.336312542973268, 'agent_1': -18.336312542973268} at episode 3300, timestep 82500, epsilon 0.1
# running rewards: {'agent_0': -18.867887999712842, 'agent_1': -18.867887999712842} at episode 3350, timestep 83750, epsilon 0.1
# running rewards: {'agent_0': -19.28738164764138, 'agent_1': -19.28738164764138} at episode 3400, timestep 85000, epsilon 0.1
# running rewards: {'agent_0': -19.353680759152788, 'agent_1': -19.353680759152788} at episode 3450, timestep 86250, epsilon 0.1
# running rewards: {'agent_0': -19.48905602110559, 'agent_1': -19.48905602110559} at episode 3500, timestep 87500, epsilon 0.1
# running rewards: {'agent_0': -19.32402987683606, 'agent_1': -19.32402987683606} at episode 3550, timestep 88750, epsilon 0.1
# running rewards: {'agent_0': -19.56910281755049, 'agent_1': -19.56910281755049} at episode 3600, timestep 90000, epsilon 0.1
# running rewards: {'agent_0': -19.597832233167594, 'agent_1': -19.597832233167594} at episode 3650, timestep 91250, epsilon 0.1
# running rewards: {'agent_0': -19.755442394667934, 'agent_1': -19.755442394667934} at episode 3700, timestep 92500, epsilon 0.1
# running rewards: {'agent_0': -19.513622802315087, 'agent_1': -19.513622802315087} at episode 3750, timestep 93750, epsilon 0.1
# running rewards: {'agent_0': -18.616670464967502, 'agent_1': -18.616670464967502} at episode 3800, timestep 95000, epsilon 0.1
# running rewards: {'agent_0': -18.961294333456724, 'agent_1': -18.961294333456724} at episode 3850, timestep 96250, epsilon 0.1
# running rewards: {'agent_0': -20.364386184242413, 'agent_1': -20.364386184242413} at episode 3900, timestep 97500, epsilon 0.1
# running rewards: {'agent_0': -20.317030786396145, 'agent_1': -20.317030786396145} at episode 3950, timestep 98750, epsilon 0.1
# running rewards: {'agent_0': -19.2669519981314, 'agent_1': -19.2669519981314} at episode 4000, timestep 100000, epsilon 0.1
# running rewards: {'agent_0': -19.328631931609017, 'agent_1': -19.328631931609017} at episode 4050, timestep 101250, epsilon 0.1
# running rewards: {'agent_0': -19.033453196329187, 'agent_1': -19.033453196329187} at episode 4100, timestep 102500, epsilon 0.1
# running rewards: {'agent_0': -19.378797120255946, 'agent_1': -19.378797120255946} at episode 4150, timestep 103750, epsilon 0.1
# running rewards: {'agent_0': -19.676000556833376, 'agent_1': -19.676000556833376} at episode 4200, timestep 105000, epsilon 0.1
# running rewards: {'agent_0': -19.3897785584248, 'agent_1': -19.3897785584248} at episode 4250, timestep 106250, epsilon 0.1
# running rewards: {'agent_0': -19.504937532917598, 'agent_1': -19.504937532917598} at episode 4300, timestep 107500, epsilon 0.1
# running rewards: {'agent_0': -19.273139333251507, 'agent_1': -19.273139333251507} at episode 4350, timestep 108750, epsilon 0.1
# running rewards: {'agent_0': -18.8255237826521, 'agent_1': -18.8255237826521} at episode 4400, timestep 110000, epsilon 0.1
# running rewards: {'agent_0': -19.0564887351986, 'agent_1': -19.0564887351986} at episode 4450, timestep 111250, epsilon 0.1
# running rewards: {'agent_0': -19.016063805604865, 'agent_1': -19.016063805604865} at episode 4500, timestep 112500, epsilon 0.1
# running rewards: {'agent_0': -18.593936845287722, 'agent_1': -18.593936845287722} at episode 4550, timestep 113750, epsilon 0.1
# running rewards: {'agent_0': -19.36620873565386, 'agent_1': -19.36620873565386} at episode 4600, timestep 115000, epsilon 0.1
# running rewards: {'agent_0': -19.97035972330954, 'agent_1': -19.97035972330954} at episode 4650, timestep 116250, epsilon 0.1
# running rewards: {'agent_0': -19.535947503689034, 'agent_1': -19.535947503689034} at episode 4700, timestep 117500, epsilon 0.1
# running rewards: {'agent_0': -18.947904647853758, 'agent_1': -18.947904647853758} at episode 4750, timestep 118750, epsilon 0.1
# running rewards: {'agent_0': -18.928731857397935, 'agent_1': -18.928731857397935} at episode 4800, timestep 120000, epsilon 0.1
# running rewards: {'agent_0': -19.036471612280348, 'agent_1': -19.036471612280348} at episode 4850, timestep 121250, epsilon 0.1
# running rewards: {'agent_0': -18.76384502272483, 'agent_1': -18.76384502272483} at episode 4900, timestep 122500, epsilon 0.1
# running rewards: {'agent_0': -19.118774872542446, 'agent_1': -19.118774872542446} at episode 4950, timestep 123750, epsilon 0.1
# running rewards: {'agent_0': -19.70561191247213, 'agent_1': -19.70561191247213} at episode 5000, timestep 125000, epsilon 0.1

# %%
# Training Plots (for Debugging)
env.reset()  # Reset env to make sure agent list isn't empty

for agent in env.agents:
    # Raw Reward
    plt.title(f"{agent}: Reward / Episode")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.plot(np.arange(len(episode_reward_history[agent])), episode_reward_history[agent])
    plt.show()

# Rolling Average Reward:
def moving_average(x, w):
    # Source: https://stackoverflow.com/a/54628145
    return np.convolve(x, np.ones(w), 'valid') / w

for agent in env.agents:
    rolling_means = moving_average(episode_reward_history[agent], 100)

    # Rolling Average
    plt.title(f"{agent}: Rolling Mean Reward")
    plt.xlabel("Episode") 
    plt.ylabel("Average Total Reward (Last 100 Episodes)")
    plt.plot(np.arange(len(rolling_means)) + 100, rolling_means)
    plt.show()

for agent in env.agents:
    # Loss Trend
    plt.title(f"{agent}: Loss History")
    plt.xlabel("Training Step") 
    plt.ylabel("Loss")
    plt.plot(np.arange(len(loss_history[agent])), loss_history[agent])
    plt.show()

for agent in env.agents:
    # Avg. Max Q Trend
    plt.title(f"{agent}: Avg. Max Q Value History")
    plt.xlabel("Episode") 
    plt.ylabel("Avg. Max Q Value")
    plt.plot(np.arange(len(avg_max_Q_history[agent])), avg_max_Q_history[agent])
    plt.show()

# %% [markdown]
# ## Final Evaluation

# %%
def eval_greedy_model(env, models):
    env.reset()  # Reset env to make sure agent list isn't empty

    # Tracking values
    final_eval_rewards = {agent: [] for agent in env.agents}
    
    #update to 500 for gif looping
    for episode in range(500):
        observations, _ = env.reset()
        episode_rewards = {agent: 0 for agent in env.agents}

        while env.agents:
            actions = select_actions(env, observations, models, epsilon=0)

            # Follow selected actions
            observations_next, rewards, _, _, _ = env.step(actions)
            
            # Save action results
            for agent in rewards.keys():
                episode_rewards[agent] += rewards[agent]

            observations = observations_next

        # Record tracking statistics:
        for agent, episode_reward in episode_rewards.items():
            final_eval_rewards[agent].append(episode_reward)


    avg_greedy_reward = {
        agent: np.mean(final_eval_reward)
        for agent, final_eval_reward in final_eval_rewards.items()
    }

    return avg_greedy_reward, final_eval_rewards

# %%
avg_greedy_reward, final_eval_rewards = eval_greedy_model(env, models)

print(avg_greedy_reward)

env.reset()  # Reset env to make sure agent list isn't empty

for agent in env.agents:
    # Raw Reward
    plt.title("Reward / Episode")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.plot(np.arange(len(final_eval_rewards[agent])), final_eval_rewards[agent])
    plt.show()
# Out:
# {'agent_0': -19.560525543329234, 'agent_1': -19.560525543329234}

# %%
# Visualize full episode
rendered_env = simple_spread_comms.parallel_env(n_agents = 2, n_landmarks = 2, comm_mode=4, render_mode="rgb_array")
frames = []

observations, _ = rendered_env.reset()
frames.append(rendered_env.render())
print("Input shape:", observations[agent].shape)

while rendered_env.agents:
    # this is where you would insert your policy
    actions = select_actions(rendered_env, observations, models, epsilon=0)

    observations, _, _, _, _ = rendered_env.step(actions)
    frames.append(rendered_env.render())

rendered_env.close()

imageio.mimwrite(
    "rendered_episode.gif",
    frames,
    loop=0  # Infinite loop gif
)
# Out:
# Input shape: (11,)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 11
#       7 print("Input shape:", observations[agent].shape)
#       9 while rendered_env.agents:
#      10     # this is where you would insert your policy
# ---> 11     actions = select_actions(rendered_env, observations, models, epsilon=0)
#      13     observations, _, _, _, _ = rendered_env.step(actions)
#      14     frames.append(rendered_env.render())
#
# Cell In[3], line 100, in select_actions(env, observations, models, epsilon)
#      98     for agent, model in models.items():
#      99         model.main.eval()
# --> 100         actions[agent] = model.main(
#     101             # Observation (state) as tensor
#     102             torch.tensor(observations[agent]).to(DEVICE)
#     103         ).argmax(dim=-1).item()
#     105 return actions
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[3], line 59, in DQN.forward(self, X, targets)
#      57 def forward(self, X, targets=None):
#      58     for layer in self.layers:
# ---> 59         X = layer(X)
#      61     # Final layer's output is the logits:
#      62     logits = X
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x11 and 13x128)
